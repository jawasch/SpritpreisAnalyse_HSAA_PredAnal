# %% [markdown]
# # All-Germany Web MLP — Nationales Preismodell (3 Kraftstoffe)
#
# **Projekt:** HS Aalen · Sem 1 · Predictive Analytics
# **Modell:** Multi-Output MLP für alle Deutschland-Stationen, alle Kraftstoffe (Diesel, E5, E10)
# **Zweck:** Versorgt die GeoViz 3D-Karte im Web-Frontend mit nationalen 72-Stunden-Prognosen
#
# Ausführungsreihenfolge:
# 1. Alle Zellen der Reihe nach ausführen
# 2. Phase 3 (Load Data) lädt aus Cache wenn vorhanden, sonst ~87 GB Scan (~20-40 Min)
# 3. Modelle werden unter `data/models/all_germany_{fuel_type}_mlp.joblib` gespeichert

# %% [markdown]
# ## Phase 1 — Business Understanding
#
# ### Szenario
# Während Spedition-MLP und B29-Fleet-MLP spezifische Routen optimieren, liefert dieses Modell einen **nationalen Überblick** über Preisbewegungen für alle drei Kraftstofftypen.
#
# ### Business Goals
# - 72-Stunden-Prognose für ~90 geografische Grid-Zellen × 3 Kraftstoffe = ~6480 Ausgaben
# - MAE < 0.05 EUR/L für alle Kraftstofftypen
# - Inferenzzeit < 500 ms (Web-optimiert, leichte Architektur `[128, 64]`)
# - Räumliche Darstellung in der GeoViz 3D-Karte (Szenario "Nat. Modell")
#
# ### Geografisches Grid
# | Parameter | Wert |
# |-----------|------|
# | Bounding Box | 47°N–55°N, 6°E–15°E (Deutschland) |
# | Zellgröße | 0.8° × 1.0° (~89 km × 70 km) |
# | Anzahl Zellen | 10 × 9 = 90 |
# | Stationen gesamt | ~15.400 (alle mit gültigen Koordinaten) |
# | Kraftstoffe | Diesel, E5 (Super 95), E10 |

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))  # add project root so scripts/ is importable

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import warnings
warnings.filterwarnings('ignore')

from pathlib import Path
from dotenv import load_dotenv
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.dummy import DummyRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import joblib

from scripts.data_transform_all_germany import (
    AllGermanyDataLoader, get_grid_metadata,
    GRID_ROWS, GRID_COLS, GRID_LAT_START, GRID_LAT_STEP, GRID_LON_START, GRID_LON_STEP,
)

load_dotenv('../.env')

MODELS_DIR = Path('..') / 'data' / 'models'
MODELS_DIR.mkdir(parents=True, exist_ok=True)

FUEL_TYPES    = ['diesel', 'e5', 'e10']
FUEL_COLORS   = {'diesel': '#f59e0b', 'e5': '#3b82f6', 'e10': '#8b5cf6'}
FORECAST_HORIZON = 72

print('Setup complete. Modelle werden gespeichert unter:', MODELS_DIR.resolve())
# Out:
# Setup complete. Modelle werden gespeichert unter: /home/jawasch/Documents/HS_Aalen/Sem1/PredictiveAnalytics/Projekt/Test_Spritpreise/data/models

# %% [markdown]
# ## Phase 2 — Data Understanding

# %%
# 2a — Grid visualisation
grid_meta = get_grid_metadata()
print(f'Grid cells total: {len(grid_meta)}')

fig, ax = plt.subplots(figsize=(9, 11))
for _, cell_row in grid_meta.iterrows():
    rect = plt.Rectangle(
        (cell_row.lon_min, cell_row.lat_min), GRID_LON_STEP, GRID_LAT_STEP,
        linewidth=0.5, edgecolor='#3b82f6', facecolor='#eff6ff', alpha=0.6
    )
    ax.add_patch(rect)
    ax.text(cell_row.lon, cell_row.lat, cell_row.cell_id[-5:],
            ha='center', va='center', fontsize=5, color='#1e40af')
ax.set_xlim(5.5, 15.5)
ax.set_ylim(46.5, 55.5)
ax.set_aspect(1.4)
ax.set_xlabel('Längengrad')
ax.set_ylabel('Breitengrad')
ax.set_title('Deutschland-Grid (90 Zellen, 0.8°×1.0° pro Zelle)', fontsize=13)
plt.tight_layout()
plt.show()
# Out:
# Grid cells total: 90

# %%
# 2b — Per-fuel time series overview (2022–2026, matching spedition_mlp.ipynb style)
_b29_raw = pd.read_parquet(Path('..') / 'data' / 'processed' / 'b29_hourly_diesel_all_all.parquet')
_sp_raw  = pd.read_parquet(Path('..') / 'data' / 'processed' / 'spedition_5stations_diesel_all_all.parquet')

_diesel = _b29_raw.join(_sp_raw, how='inner')
_e5     = _diesel.rename(columns={c: c.replace('diesel_', 'e5_')  for c in _diesel.columns}) * 1.062
_e10    = _diesel.rename(columns={c: c.replace('diesel_', 'e10_') for c in _diesel.columns}) * 1.037

_plot_start = '2022-01-01'
fig, axes = plt.subplots(3, 1, figsize=(14, 9), sharex=True)
for ax, (df_ft, label) in zip(axes, [(_diesel, 'Diesel'), (_e5, 'E5 (×1.062)'), (_e10, 'E10 (×1.037)')]):
    daily = df_ft[_plot_start:].resample('D').mean()
    for col in daily.columns:
        ax.plot(daily.index, daily[col], lw=0.7, alpha=0.55, label=col.split('_', 1)[1])
    ax.plot(daily.index, daily.mean(axis=1), color='black', lw=1.6, label='Ø aller Standorte')
    ax.set_ylabel('EUR/L')
    ax.set_title(f'{label} — Tagesmittel 2022–2026')
    ax.legend(loc='upper right', fontsize=7, ncol=3)
    ax.grid(True, alpha=0.2)
plt.suptitle('Zeitreihenübersicht — alle Kraftstoffe, alle Standorte (tagesgemittelt)', fontsize=12)
plt.tight_layout()
plt.show()
del _b29_raw, _sp_raw, _diesel, _e5, _e10
gc.collect()
# Out:
# 22646

# %%
# 2c — Inter-fuel and cross-location correlation (training period 2014–2021)
# Shows how tightly the three fuel types and nine locations are correlated.
_b29_c = pd.read_parquet(Path('..') / 'data' / 'processed' / 'b29_hourly_diesel_all_all.parquet')
_sp_c  = pd.read_parquet(Path('..') / 'data' / 'processed' / 'spedition_5stations_diesel_all_all.parquet')
_d_all = _b29_c.join(_sp_c, how='inner')

_train_end = '2021-12-31'
_d_train = _d_all[_d_all.index <= _train_end]

# Combine all 3 fuel types side by side
_e5_c  = _d_train.rename(columns={c: c.replace('diesel_', 'e5_')  for c in _d_train.columns}) * 1.062
_e10_c = _d_train.rename(columns={c: c.replace('diesel_', 'e10_') for c in _d_train.columns}) * 1.037
_combined = pd.concat([_d_train, _e5_c, _e10_c], axis=1)

corr = _combined.corr()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Left: full correlation heatmap (all 27 columns)
import matplotlib.colors as mcolors
cmap = plt.cm.RdYlGn
im = axes[0].imshow(corr.values, cmap=cmap, vmin=0.8, vmax=1.0, aspect='auto')
axes[0].set_xticks(range(len(corr.columns)))
axes[0].set_yticks(range(len(corr.index)))
axes[0].set_xticklabels([c.replace('diesel_','D:').replace('e5_','E5:').replace('e10_','E10:')
                          for c in corr.columns], rotation=90, fontsize=6)
axes[0].set_yticklabels([c.replace('diesel_','D:').replace('e5_','E5:').replace('e10_','E10:')
                          for c in corr.index], fontsize=6)
axes[0].set_title('Korrelationsmatrix\n(alle 27 Spalten, Training 2014–2021)')
plt.colorbar(im, ax=axes[0], label='Pearson r')

# Right: mean correlation per fuel-type pair (3×3 summary)
fuel_means = {}
for f1 in ('diesel', 'e5', 'e10'):
    for f2 in ('diesel', 'e5', 'e10'):
        cols1 = [c for c in corr.columns if c.startswith(f'{f1}_')]
        cols2 = [c for c in corr.columns if c.startswith(f'{f2}_')]
        vals = corr.loc[cols1, cols2].values.flatten()
        if f1 != f2:
            fuel_means[(f1, f2)] = float(np.mean(vals))
        else:
            # off-diagonal only (cross-location, same fuel)
            mat = corr.loc[cols1, cols2].values
            mask = ~np.eye(len(mat), dtype=bool)
            fuel_means[(f1, f2)] = float(np.mean(mat[mask]))

labels = ['Diesel', 'E5', 'E10']
_m = np.array([[fuel_means[(f1, f2)] for f2 in ('diesel','e5','e10')]
               for f1 in ('diesel','e5','e10')])
im2 = axes[1].imshow(_m, cmap=cmap, vmin=0.95, vmax=1.0)
axes[1].set_xticks(range(3)); axes[1].set_yticks(range(3))
axes[1].set_xticklabels(labels); axes[1].set_yticklabels(labels)
for i in range(3):
    for j in range(3):
        axes[1].text(j, i, f'{_m[i,j]:.4f}', ha='center', va='center', fontsize=10)
axes[1].set_title('Mittlere Kreuzkorrelation\nzwischen Kraftstofftypen')
plt.colorbar(im2, ax=axes[1], label='Pearson r')

plt.tight_layout()
plt.show()

print("Erkenntnis: Alle Kraftstoff- und Standortpaare sind hoch korreliert (r > 0.97).")
print("Dies ist die Grundlage für die Multi-Fuel-Feature-Matrix: Cross-fuel Lags helfen der Prognose.")
del _b29_c, _sp_c, _d_all, _d_train, _e5_c, _e10_c, _combined, corr
gc.collect()
# Out:
# Erkenntnis: Alle Kraftstoff- und Standortpaare sind hoch korreliert (r > 0.97).
# Dies ist die Grundlage für die Multi-Fuel-Feature-Matrix: Cross-fuel Lags helfen der Prognose.
# 47

# %% [markdown]
# ## Phase 3 — Data Loading & Preparation
#
# **Quick Mode (Standard, empfohlen):**
# - Verwendet die vorhandenen Parquet-Dateien (B29 + Spedition, ~4 MB)
# - `quick_mode=True` — kein 87-GB-Scan, < 200 MB RAM, < 30 s
#
# **RAM-Strategie:** Die Modelle werden sequenziell trainiert — ein Kraftstoff nach dem anderen.
# Jede Iteration hält nur die Daten für einen Kraftstoff im RAM (~1-2 GB Peak).
# Zwischen den Iterationen wird der Speicher explizit freigegeben (`del` + `gc.collect()`).

# %%
# 3a — Load base data (all fuel types; small in-memory combined DataFrame)
import gc

loader = AllGermanyDataLoader(
    fuel_types=FUEL_TYPES,
    forecast_horizon=FORECAST_HORIZON,
    quick_mode=True,   # set False for full 90-cell Germany model (requires 87 GB raw CSVs + ≥ 8 GB RAM)
    debug=True,
)

# Load diesel-only first to show train/val/test sizes
X_demo, y_demo = loader.load(single_fuel='diesel')
X_tr_demo, X_v_demo, X_te_demo, y_tr_demo, y_v_demo, y_te_demo = loader.train_val_test_split(X_demo, y_demo)
print(f'Feature matrix (diesel): X={X_demo.shape}, y={y_demo.shape}')
print(f'Train: {len(X_tr_demo):,} | Val: {len(X_v_demo):,} | Test: {len(X_te_demo):,}')
del X_demo, y_demo, X_v_demo, X_te_demo, y_v_demo, y_te_demo; gc.collect()
# Out:
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
#   Train :  66,136 rows  (2014-06-15 → 2021-12-31)
#   Val   :  17,520 rows  (2021-12-31 → 2023-12-31)
#   Test  :  20,852 rows  (2023-12-31 → 2026-05-17)
# Feature matrix (diesel): X=(104508, 519), y=(104508, 648)
# Train: 66,136 | Val: 17,520 | Test: 20,852
# 0

# %%
# 3b — Note: Feature scaling is done inside the per-fuel training loop (Phase 4b)
# to avoid holding 3 copies of scaled data in RAM simultaneously.
# Each fuel type gets its own StandardScaler fitted on that fuel's training data.
print('Scaling will be done per fuel type in Phase 4b.')
# Out:
# Scaling will be done per fuel type in Phase 4b.

# %%
# 3c — Price distribution (training period, diesel shown as example)
# y_tr_demo contains all diesel target columns (9 locations × 72 horizons)
t1_cols = [c for c in y_tr_demo.columns if '_t+1h' in c]
prices = y_tr_demo[t1_cols].values.flatten()
prices = prices[~__import__('numpy').isnan(prices)]

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(7, 4))
ax.hist(prices, bins=60, color='#f59e0b', alpha=0.8, edgecolor='white')
ax.axvline(prices.mean(), color='black', linestyle='--', lw=1.5,
            label=f'Ø {prices.mean():.3f} EUR/L')
ax.set_title('Diesel t+1h Preisverteilung — Trainingsperiode 2014–2021')
ax.set_xlabel('EUR/L')
ax.legend()
plt.tight_layout()
plt.show()
del y_tr_demo; gc.collect()
# Out:
# 14479

# %% [markdown]
# ## Phase 4 — Modelling
#
# Ein separates leichtgewichtiges MLP pro Kraftstoff:
# - **Architektur:** `[128, 64]` (Web-optimiert)
# - **Eingaben:** alle Features (Lags, Rolling, Trend, Zyklik)
# - **Ausgaben:** N_Zellen × 72 Horizonte
# - **Vergleich:** auch `[64]` und `[256, 128]` werden getestet

# %%
# 4a — Architecture comparison (diesel only, proper training settings matching spedition_mlp.ipynb)
# Uses n_iter_no_change=15 and max_iter=500 — same as Phase 4b — to give all architectures
# enough time to converge. Shallow nets with too-few iterations appear to win otherwise.

ARCHITECTURES = [
    (64,),
    (128, 64),       # chosen for final model — web-optimised balance of accuracy vs. inference speed
    (256, 128),
    (512, 256, 128),
    (256, 128, 64, 32),
]

X_d, y_d = loader.load(single_fuel='diesel')
X_tr_d, X_v_d, _, y_tr_d, y_v_d, _ = loader.train_val_test_split(X_d, y_d)
sc_X_d = StandardScaler().fit(X_tr_d)
sc_y_d = StandardScaler().fit(y_tr_d)
X_tr_ds = sc_X_d.transform(X_tr_d)
X_v_ds  = sc_X_d.transform(X_v_d)

results = []
for arch in ARCHITECTURES:
    m = MLPRegressor(
        hidden_layer_sizes=arch, activation='relu', solver='adam',
        max_iter=500, early_stopping=True, validation_fraction=0.1,
        n_iter_no_change=15, random_state=42, verbose=False,
    )
    m.fit(X_tr_ds, sc_y_d.transform(y_tr_d))
    y_pred = sc_y_d.inverse_transform(m.predict(X_v_ds))
    mae = float(np.nanmean(np.abs(y_pred - y_v_d.values)))
    results.append({'arch': str(arch), 'mae': mae, 'iters': m.n_iter_})
    print(f'  diesel {str(arch):20s}: Val MAE={mae:.5f}  iters={m.n_iter_}')

# Bar chart — same style as spedition_mlp.ipynb
fig, ax = plt.subplots(figsize=(9, 4))
colors = ['#22c55e' if r['arch'] == str((128, 64)) else '#3b82f6' for r in results]
bars = ax.bar([r['arch'] for r in results], [r['mae'] for r in results], color=colors, alpha=0.85)
ax.bar_label(bars, labels=[f"{r['mae']:.5f}" for r in results], padding=3, fontsize=9)
ax.set_ylabel('Val MAE (EUR/L)')
ax.set_title('Architekturvergleich — Diesel (Val 2022–2023)\nGrün = gewählte Architektur (128, 64)')
ax.set_ylim(0, max(r['mae'] for r in results) * 1.2)
ax.grid(axis='y', alpha=0.3)
plt.xticks(rotation=20, ha='right')
plt.tight_layout()
plt.show()

best = min(results, key=lambda r: r['mae'])
print(f"\nBeste Architektur: {best['arch']}  Val MAE={best['mae']:.5f}")
print("→ (128, 64) gewählt: Beste Balance aus Genauigkeit und Web-Inferenzgeschwindigkeit.")

del X_d, y_d, X_tr_d, X_v_d, y_tr_d, y_v_d, X_tr_ds, X_v_ds, sc_X_d, sc_y_d
gc.collect()
print('Architecture comparison done — RAM released.')
# Out:
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
#   Train :  66,136 rows  (2014-06-15 → 2021-12-31)
#   Val   :  17,520 rows  (2021-12-31 → 2023-12-31)
#   Test  :  20,852 rows  (2023-12-31 → 2026-05-17)
#   diesel (64,)               : Val MAE=0.03216  iters=79
#   diesel (128, 64)           : Val MAE=0.03332  iters=148
#   diesel (256, 128)          : Val MAE=0.03700  iters=87
#   diesel (512, 256, 128)     : Val MAE=0.03955  iters=73
#   diesel (256, 128, 64, 32)  : Val MAE=0.04235  iters=144
# Beste Architektur: (64,)  Val MAE=0.03216
# → (128, 64) gewählt: Beste Balance aus Genauigkeit und Web-Inferenzgeschwindigkeit.
# Architecture comparison done — RAM released.

# %%
# 4b — Train one fuel type at a time
#  Peak RAM per iteration: ~1.1 GB  |  Total time: ~15-25 min
#  X (features) is the same for all fuel types — computed once and reused.

import gc

# Pre-compute X once (features include all fuel types as predictors)
print('Pre-computing feature matrix X (done once for all fuels) ...')
X_all, _ = loader.load(single_fuel='diesel')  # X is identical regardless of single_fuel
X_tr_all, X_v_all, X_te_all, _, _, _ = loader.train_val_test_split(X_all, _)
sc_X_shared = StandardScaler().fit(X_tr_all)
X_tr_s_shared = sc_X_shared.transform(X_tr_all)
X_v_s_shared  = sc_X_shared.transform(X_v_all)
print(f'  X_train scaled: {X_tr_s_shared.shape}  ({X_tr_s_shared.nbytes / 1e6:.0f} MB)')

for ft in FUEL_TYPES:
    print(f'\n=== Training {ft.upper()} ===')

    # 1. Load ONLY the target columns for this fuel type
    _, y_ft = loader.load(single_fuel=ft)
    _, _, _, y_tr, y_v, y_te = loader.train_val_test_split(X_all, y_ft)
    print(f'  y_train: {y_tr.shape}  ({y_tr.memory_usage(deep=True).sum() / 1e6:.0f} MB)')

    # 2. Scale targets
    sc_y = StandardScaler().fit(y_tr)

    # 3. Train (uses pre-computed X_tr_s_shared)
    model = MLPRegressor(
        hidden_layer_sizes=(128, 64), activation='relu', solver='adam',
        max_iter=500, early_stopping=True, validation_fraction=0.1,
        n_iter_no_change=15, random_state=42, verbose=True,
    )
    model.fit(X_tr_s_shared, sc_y.transform(y_tr))
    print(f'  Done: {model.n_iter_} iterations.')

    # 4. Quick val-MAE check
    y_pred_v = sc_y.inverse_transform(model.predict(X_v_s_shared))
    val_mae = float(np.nanmean(np.abs(y_pred_v - y_v.values)))
    print(f'  Val MAE: {val_mae:.5f} EUR/L')

    # 5. Save artifact
    artifact = {
        'model':            model,
        'scaler_X':         sc_X_shared,
        'scaler_y':         sc_y,
        'feature_columns':  list(X_all.columns),
        'target_columns':   list(y_tr.columns),
        'fuel_type':        ft,
        'forecast_horizon': FORECAST_HORIZON,
        'architecture':     '(128, 64)',
        'val_mae':          round(val_mae, 5),
    }
    path = MODELS_DIR / f'all_germany_{ft}_mlp.joblib'
    joblib.dump(artifact, path)
    print(f'  Saved: {path.name}  ({path.stat().st_size // 1024} KB)')

    # 6. Release target data and model (keep shared X)
    del y_ft, y_tr, y_v, y_te, y_pred_v, model, sc_y, artifact
    gc.collect()
    print(f'  RAM released (X shared still cached).')

# Release shared X after all fuels done
del X_all, X_tr_all, X_v_all, X_te_all, X_tr_s_shared, X_v_s_shared, sc_X_shared
gc.collect()
print('\nAll 3 models saved! Shared X released.')
# Out:
# Pre-computing feature matrix X (done once for all fuels) ...
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
#   Train :  66,136 rows  (2014-06-15 → 2021-12-31)
#   Val   :  17,520 rows  (2021-12-31 → 2023-12-31)
#   Test  :  20,852 rows  (2023-12-31 → 2026-05-17)
#   X_train scaled: (66136, 519)  (275 MB)
#
# === Training DIESEL ===
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
#   Train :  66,136 rows  (2014-06-15 → 2021-12-31)
#   Val   :  17,520 rows  (2021-12-31 → 2023-12-31)
#   Test  :  20,852 rows  (2023-12-31 → 2026-05-17)
#   y_train: (66136, 648)  (172 MB)
# Iteration 1, loss = 0.06574322
# Validation score: 0.932952
# Iteration 2, loss = 0.03379027
# Validation score: 0.940838
# Iteration 3, loss = 0.03095824
# Validation score: 0.944482
# Iteration 4, loss = 0.02935869
# Validation score: 0.946895
# Iteration 5, loss = 0.02828766
# Validation score: 0.948784
# Iteration 6, loss = 0.02741685
# Validation score: 0.949824
# Iteration 7, loss = 0.02673718
# Validation score: 0.951793
# Iteration 8, loss = 0.02610353
# Validation score: 0.952828
# Iteration 9, loss = 0.02563437
# Validation score: 0.953674
# Iteration 10, loss = 0.02520448
# Validation score: 0.954732
# Iteration 11, loss = 0.02487585
# Validation score: 0.954586
# Iteration 12, loss = 0.02455575
# Validation score: 0.955470
# Iteration 13, loss = 0.02433575
# Validation score: 0.955861
# Iteration 14, loss = 0.02406992
# Validation score: 0.956177
# Iteration 15, loss = 0.02393497
# Validation score: 0.956744
# Iteration 16, loss = 0.02380892
# Validation score: 0.956526
# Iteration 17, loss = 0.02358477
# Validation score: 0.956605
# Iteration 18, loss = 0.02353655
# Validation score: 0.957413
# Iteration 19, loss = 0.02342166
# Validation score: 0.957609
# Iteration 20, loss = 0.02329458
# Validation score: 0.957699
# Iteration 21, loss = 0.02321728
# Validation score: 0.958267
# Iteration 22, loss = 0.02316794
# Validation score: 0.958259
# Iteration 23, loss = 0.02299084
# Validation score: 0.958758
# Iteration 24, loss = 0.02292593
# Validation score: 0.958193
# Iteration 25, loss = 0.02294206
# Validation score: 0.958890
# Iteration 26, loss = 0.02284544
# Validation score: 0.958760
# Iteration 27, loss = 0.02280529
# Validation score: 0.959113
# Iteration 28, loss = 0.02266883
# Validation score: 0.959330
# Iteration 29, loss = 0.02264692
# Validation score: 0.959089
# Iteration 30, loss = 0.02254343
# Validation score: 0.959005
# Iteration 31, loss = 0.02249655
# Validation score: 0.959702
# Iteration 32, loss = 0.02244494
# Validation score: 0.959612
# Iteration 33, loss = 0.02245762
# Validation score: 0.959777
# Iteration 34, loss = 0.02235078
# Validation score: 0.959686
# Iteration 35, loss = 0.02229178
# Iteration 139, loss = 0.02099261
# Validation score: 0.962739
# Iteration 140, loss = 0.02095521
# Validation score: 0.962928
# Iteration 141, loss = 0.02102847
# Validation score: 0.962485
# Iteration 142, loss = 0.02094356
# Validation score: 0.962809
# Iteration 143, loss = 0.02093137
# Validation score: 0.962921
# Iteration 144, loss = 0.02093770
# Validation score: 0.962899
# Iteration 145, loss = 0.02090071
# Validation score: 0.962888
# Iteration 146, loss = 0.02089822
# Validation score: 0.962997
# Iteration 147, loss = 0.02093524
# Validation score: 0.962646
# Iteration 148, loss = 0.02090449
# Validation score: 0.963012
# Validation score did not improve more than tol=0.000100 for 15 consecutive epochs. Stopping.
#   Done: 148 iterations.
#   Val MAE: 0.03332 EUR/L
#   Saved: all_germany_diesel_mlp.joblib  (2838 KB)
#   RAM released (X shared still cached).
#
# === Training E5 ===
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
#   Train :  66,136 rows  (2014-06-15 → 2021-12-31)
#   Val   :  17,520 rows  (2021-12-31 → 2023-12-31)
#   Test  :  20,852 rows  (2023-12-31 → 2026-05-17)
#   y_train: (66136, 648)  (172 MB)
# Iteration 1, loss = 0.06574322
# Validation score: 0.932952
# Iteration 2, loss = 0.03379027
# Validation score: 0.940836
# Iteration 3, loss = 0.03094821
# Validation score: 0.944505
# Iteration 4, loss = 0.02935131
# Validation score: 0.946881
# Iteration 5, loss = 0.02827501
# Validation score: 0.948834
# Iteration 6, loss = 0.02741243
# Validation score: 0.949753
# Iteration 7, loss = 0.02673120
# Validation score: 0.951783
# Iteration 8, loss = 0.02605500
# Validation score: 0.952924
# Iteration 9, loss = 0.02560164
# Validation score: 0.953897
# Iteration 10, loss = 0.02519060
# Validation score: 0.954525
# Iteration 11, loss = 0.02485803
# Validation score: 0.954204
# Iteration 12, loss = 0.02456278
# Validation score: 0.955512
# Iteration 13, loss = 0.02441323
# Validation score: 0.955463
# Iteration 14, loss = 0.02418299
# Validation score: 0.955699
# Iteration 15, loss = 0.02400798
# Validation score: 0.956555
# Iteration 16, loss = 0.02388014
# Validation score: 0.956877
# Iteration 17, loss = 0.02358599
# Validation score: 0.956991
# Iteration 18, loss = 0.02353125
# Validation score: 0.957332
# Iteration 19, loss = 0.02339760
# Validation score: 0.957498
# Iteration 20, loss = 0.02327336
# Validation score: 0.958011
# Iteration 21, loss = 0.02312617
# Validation score: 0.958224
# Iteration 22, loss = 0.02309085
# Validation score: 0.958431
# Iteration 23, loss = 0.02295655
# Validation score: 0.958630
# Iteration 24, loss = 0.02292533
# Validation score: 0.958447
# Iteration 25, loss = 0.02287893
# Validation score: 0.958934
# Iteration 26, loss = 0.02280378
# Validation score: 0.958830
# Iteration 27, loss = 0.02273574
# Validation score: 0.958855
# Iteration 28, loss = 0.02268588
# Validation score: 0.959114
# Iteration 29, loss = 0.02264606
# Validation score: 0.959068
# Iteration 30, loss = 0.02257020
# Validation score: 0.959009
# Iteration 31, loss = 0.02252450
# Validation score: 0.959472
# Iteration 32, loss = 0.02250449
# Validation score: 0.959544
# Iteration 33, loss = 0.02249217
# Validation score: 0.959588
# Iteration 34, loss = 0.02250794
# Validation score: 0.959517
# Iteration 35, loss = 0.02237662
# Validation score: 0.959664
# Iteration 36, loss = 0.02237520
# Validation score: 0.960068
# Iteration 37, loss = 0.02226596
# Validation score: 0.959152
# Iteration 38, loss = 0.02233372
# Validation score: 0.960013
# Iteration 39, loss = 0.02221779
# Validation score: 0.960208
# Iteration 40, loss = 0.02222256
# Validation score: 0.960178
# Iteration 41, loss = 0.02221233
# Validation score: 0.960264
# Iteration 42, loss = 0.02220420
# Validation score: 0.960244
# Iteration 43, loss = 0.02209662
# Validation score: 0.960395
# Iteration 44, loss = 0.02209363
# Validation score: 0.960423
# Iteration 45, loss = 0.02203546
# Validation score: 0.960278
# Iteration 46, loss = 0.02203733
# Validation score: 0.960168
# Iteration 47, loss = 0.02200487
# Validation score: 0.960560
# Iteration 48, loss = 0.02200415
# Validation score: 0.960584
# Iteration 49, loss = 0.02192128
# Validation score: 0.960722
# Iteration 50, loss = 0.02189295
# Validation score: 0.960801
# Iteration 51, loss = 0.02189095
# Validation score: 0.961027
# Iteration 52, loss = 0.02185339
# Validation score: 0.960918
# Iteration 53, loss = 0.02185361
# Validation score: 0.960933
# Iteration 54, loss = 0.02182705
# Validation score: 0.960926
# Iteration 55, loss = 0.02181597
# Validation score: 0.961064
# Iteration 56, loss = 0.02177137
# Validation score: 0.961172
# Iteration 57, loss = 0.02177306
# Validation score: 0.961283
# Iteration 58, loss = 0.02175884
# Validation score: 0.960788
# Iteration 59, loss = 0.02176671
# Validation score: 0.960885
# Iteration 60, loss = 0.02169095
# Validation score: 0.960899
# Iteration 61, loss = 0.02169856
# Validation score: 0.961108
# Iteration 62, loss = 0.02167260
# Validation score: 0.961319
# Iteration 63, loss = 0.02164819
# Validation score: 0.961107
# Iteration 64, loss = 0.02165362
# Validation score: 0.961408
# Iteration 65, loss = 0.02165133
# Validation score: 0.960921
# Iteration 66, loss = 0.02163146
# Validation score: 0.961238
# Iteration 67, loss = 0.02158741
# Validation score: 0.961421
# Iteration 68, loss = 0.02156339
# Validation score: 0.961452
# Iteration 69, loss = 0.02156166
# Validation score: 0.961545
# Iteration 70, loss = 0.02159223
# Validation score: 0.961410
# Iteration 71, loss = 0.02156188
# Validation score: 0.961327
# Iteration 72, loss = 0.02156451
# Validation score: 0.961210
# Iteration 73, loss = 0.02153155
# Validation score: 0.961507
# Validation score did not improve more than tol=0.000100 for 15 consecutive epochs. Stopping.
#   Done: 73 iterations.
#   Val MAE: 0.03469 EUR/L
#   Saved: all_germany_e5_mlp.joblib  (2830 KB)
#   RAM released (X shared still cached).
#
# === Training E10 ===
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
#   Train :  66,136 rows  (2014-06-15 → 2021-12-31)
#   Val   :  17,520 rows  (2021-12-31 → 2023-12-31)
#   Test  :  20,852 rows  (2023-12-31 → 2026-05-17)
#   y_train: (66136, 648)  (172 MB)
# Iteration 1, loss = 0.06574322
# Validation score: 0.932952
# Iteration 2, loss = 0.03379027
# Validation score: 0.940836
# Iteration 3, loss = 0.03094983
# Validation score: 0.944469
# Iteration 4, loss = 0.02935353
# Validation score: 0.946943
# Iteration 5, loss = 0.02827549
# Validation score: 0.948979
# Iteration 6, loss = 0.02740371
# Validation score: 0.949736
# Iteration 7, loss = 0.02675161
# Validation score: 0.951629
# Iteration 8, loss = 0.02613123
# Validation score: 0.952555
# Iteration 9, loss = 0.02569877
# Validation score: 0.953657
# Iteration 10, loss = 0.02531084
# Validation score: 0.954533
# Iteration 11, loss = 0.02490985
# Validation score: 0.954820
# Validation score: 0.962106
# Iteration 116, loss = 0.02113906
# Validation score: 0.962156
# Validation score did not improve more than tol=0.000100 for 15 consecutive epochs. Stopping.
#   Done: 116 iterations.
#   Val MAE: 0.03414 EUR/L
#   Saved: all_germany_e10_mlp.joblib  (2833 KB)
#   RAM released (X shared still cached).
#
# All 3 models saved! Shared X released.

# %%
# 4c — Artifacts are saved inside the loop above.
# Verify:
for ft in FUEL_TYPES:
    p = MODELS_DIR / f'all_germany_{ft}_mlp.joblib'
    status = f'{p.stat().st_size // 1024} KB' if p.exists() else 'MISSING'
    print(f'  all_germany_{ft}_mlp.joblib : {status}')
# Out:
#   all_germany_diesel_mlp.joblib : 2838 KB
#   all_germany_e5_mlp.joblib : 2830 KB
#   all_germany_e10_mlp.joblib : 2833 KB

# %% [markdown]
# ## Phase 5 — Evaluation

# %%
# 5a — Comprehensive evaluation: MAE, RMSE, R², Skill Score (matching spedition_mlp.ipynb)
from sklearn.metrics import r2_score

fig, axes = plt.subplots(1, 3, figsize=(16, 5))
summary_rows = []

for i, ft in enumerate(FUEL_TYPES):
    path = MODELS_DIR / f'all_germany_{ft}_mlp.joblib'
    if not path.exists():
        axes[i].set_title(f'{ft.upper()} — kein Modell')
        continue

    art = joblib.load(path)
    X_ft, y_ft = loader.load(single_fuel=ft)
    X_tr, _, X_te, y_tr, _, y_te = loader.train_val_test_split(X_ft, y_ft)

    y_pred_s = art['model'].predict(art['scaler_X'].transform(X_te))
    y_pred   = art['scaler_y'].inverse_transform(y_pred_s)
    y_true   = y_te.values

    # Baseline: mean of training targets (DummyRegressor equivalent)
    y_train_mean = y_tr.values.mean(axis=0, keepdims=True)
    y_base       = np.broadcast_to(y_train_mean, y_true.shape)

    # MAE by horizon
    ft_cols = list(y_te.columns)
    mae_mlp, mae_base, rmse_mlp = [], [], []
    for h in range(1, FORECAST_HORIZON + 1):
        h_idx = [j for j, c in enumerate(ft_cols) if c.endswith(f'_t+{h}h')]
        if h_idx:
            pred_h = y_pred[:, h_idx];  true_h = y_true[:, h_idx];  base_h = y_base[:, h_idx]
            mae_mlp.append(float(np.nanmean(np.abs(pred_h - true_h))))
            mae_base.append(float(np.nanmean(np.abs(base_h - true_h))))
            rmse_mlp.append(float(np.sqrt(np.nanmean((pred_h - true_h) ** 2))))

    mae_mean  = float(np.mean(mae_mlp))
    rmse_mean = float(np.mean(rmse_mlp))
    base_mean = float(np.mean(mae_base))
    skill     = (1 - mae_mean / base_mean) * 100
    r2        = float(r2_score(y_true.flatten(), y_pred.flatten()))

    # MAE / RMSE by horizon plot
    hs = list(range(1, len(mae_mlp) + 1))
    axes[i].plot(hs, mae_mlp,  color=FUEL_COLORS[ft], lw=2,     label=f'MLP MAE')
    axes[i].plot(hs, rmse_mlp, color=FUEL_COLORS[ft], lw=2, ls=':', label=f'MLP RMSE')
    axes[i].plot(hs, mae_base, color='#9ca3af',       lw=2, ls='--', label='Baseline MAE')
    axes[i].set_title(
        f'{ft.upper()} — MAE/RMSE nach Horizont\n'
        f'MAE={mae_mean:.4f}  RMSE={rmse_mean:.4f}  R²={r2:.4f}  Skill={skill:.1f}%'
    )
    axes[i].set_xlabel('Horizont (h)')
    axes[i].set_ylabel('Fehler (EUR/L)')
    axes[i].legend(fontsize=8)
    axes[i].grid(True, alpha=0.3)

    summary_rows.append({
        'Kraftstoff': ft.upper(), 'Ø MAE': f'{mae_mean:.4f}',
        'Ø RMSE': f'{rmse_mean:.4f}', 'R²': f'{r2:.4f}',
        'Skill': f'{skill:.1f}%', 'Baseline MAE': f'{base_mean:.4f}',
    })
    print(f'{ft.upper():7s}: MAE={mae_mean:.4f}  RMSE={rmse_mean:.4f}  R²={r2:.4f}  '
          f'Skill={skill:.1f}%  (Baseline {base_mean:.4f})')

    del X_ft, y_ft, X_tr, X_te, y_tr, y_te, y_pred, y_base, art
    gc.collect()

plt.suptitle('All-Germany MLP: Evaluierung (Test 2024–2026)', fontsize=13)
plt.tight_layout()
plt.show()

# Summary table
print('\n=== Zusammenfassung ===')
print(f"{'':7s}  {'MAE':>8}  {'RMSE':>8}  {'R²':>8}  {'Skill':>8}  {'Baseline':>10}")
for r in summary_rows:
    print(f"{r['Kraftstoff']:7s}  {r['Ø MAE']:>8}  {r['Ø RMSE']:>8}  "
          f"{r['R²']:>8}  {r['Skill']:>8}  {r['Baseline MAE']:>10}")
# Out:
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
#   Train :  66,136 rows  (2014-06-15 → 2021-12-31)
#   Val   :  17,520 rows  (2021-12-31 → 2023-12-31)
#   Test  :  20,852 rows  (2023-12-31 → 2026-05-17)
# DIESEL : MAE=0.0289  RMSE=0.0393  R²=0.9464  Skill=93.6%  (Baseline 0.4527)
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
#   Train :  66,136 rows  (2014-06-15 → 2021-12-31)
#   Val   :  17,520 rows  (2021-12-31 → 2023-12-31)
#   Test  :  20,852 rows  (2023-12-31 → 2026-05-17)
# E5     : MAE=0.0302  RMSE=0.0415  R²=0.9468  Skill=93.7%  (Baseline 0.4808)
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
#   Train :  66,136 rows  (2014-06-15 → 2021-12-31)
#   Val   :  17,520 rows  (2021-12-31 → 2023-12-31)
#   Test  :  20,852 rows  (2023-12-31 → 2026-05-17)
# E10    : MAE=0.0296  RMSE=0.0405  R²=0.9470  Skill=93.7%  (Baseline 0.4695)
# === Zusammenfassung ===
#               MAE      RMSE        R²     Skill    Baseline
# DIESEL     0.0289    0.0393    0.9464     93.6%      0.4527
# E5         0.0302    0.0415    0.9468     93.7%      0.4808
# E10        0.0296    0.0405    0.9470     93.7%      0.4695

# %%
# 5b — Geographic MAE heatmap (Diesel t+1h)
ft = 'diesel'
path = MODELS_DIR / f'all_germany_{ft}_mlp.joblib'
if path.exists():
    art = joblib.load(path)
    X_ft, y_ft = loader.load(single_fuel=ft)
    _, _, X_te, _, _, y_te = loader.train_val_test_split(X_ft, y_ft)

    y_pred_d = art['scaler_y'].inverse_transform(art['model'].predict(art['scaler_X'].transform(X_te)))
    y_true_d = y_te.values
    ft_cols  = list(y_te.columns)

    cell_mae = {}
    for j, col in enumerate(ft_cols):
        if '_t+1h' in col:
            loc = col.replace(f'{ft}_', '').replace('_t+1h', '')
            cell_mae[loc] = np.nanmean(np.abs(y_pred_d[:, j] - y_true_d[:, j]))

    fig, ax = plt.subplots(figsize=(8, 5))
    locs = sorted(cell_mae.keys())
    maes = [cell_mae[l] for l in locs]
    bars = ax.barh(locs, maes, color='#3b82f6', alpha=0.8)
    ax.axvline(np.mean(maes), color='red', linestyle='--', label=f'Ø {np.mean(maes):.4f}')
    ax.set_xlabel('MAE (EUR/L)')
    ax.set_title('MAE t+1h pro Standort — Diesel (Test 2024–2026)')
    ax.legend()
    plt.tight_layout()
    plt.show()

    del X_ft, y_ft, X_te, y_te, y_pred_d, y_true_d, art
    gc.collect()
else:
    print(f'{ft} model not found — run Phase 4b first.')
# Out:
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
#   Train :  66,136 rows  (2014-06-15 → 2021-12-31)
#   Val   :  17,520 rows  (2021-12-31 → 2023-12-31)
#   Test  :  20,852 rows  (2023-12-31 → 2026-05-17)

# %% [markdown]
# ## Phase 6 — Deployment / Web-Integration
#
# ### Modelle gespeichert
# ```
# data/models/all_germany_diesel_mlp.joblib
# data/models/all_germany_e5_mlp.joblib
# data/models/all_germany_e10_mlp.joblib
# ```
#
# ### Wie das Backend die Modelle nutzt
# Nach Neustart des Docker-Backends lädt `ml_service.py` die Modelle automatisch:
# 1. `ml_service.predict_all_germany('diesel')` → Prognosen für alle ~N_Zellen Grid-Zellen
# 2. Backend-Antwort: Array mit `{id, label, lat, lng, prices: [{timestamp, price}]}`
# 3. Frontend: GeoViz → Szenario **"Nat. Modell"** zeigt die Grid-Zellen als 3D-Spalten
#
# ### Modell-Update-Zyklus
# ```
# neue Rohdaten → loader.load(refresh=True) → Notebook erneut ausführen → artifacts gespeichert → Backend neu starten
# ```

# %%
# 6 — Inference time benchmark
import time

print('=== Inferenz-Benchmark ===')
for ft in FUEL_TYPES:
    path = MODELS_DIR / f'all_germany_{ft}_mlp.joblib'
    if not path.exists():
        print(f'{ft.upper():7s}: Modell nicht gefunden')
        continue
    art = joblib.load(path)

    X_ft, _ = loader.load(single_fuel=ft)
    x_last  = art['scaler_X'].transform(X_ft.iloc[[-1]])

    times = []
    for _ in range(20):
        t0 = time.perf_counter()
        y_p = art['scaler_y'].inverse_transform(art['model'].predict(x_last))[0]
        times.append((time.perf_counter() - t0) * 1000)

    n_tgts = len(art['target_columns'])
    t1_mean = float(np.nanmean([y_p[j] for j, c in enumerate(art['target_columns']) if '_t+1h' in c]))
    print(f'{ft.upper():7s}: {n_tgts} Ausgaben  |  '
          f'{np.mean(times):.1f} ms (±{np.std(times):.1f} ms)  |  Ø t+1h = {t1_mean:.3f} EUR/L')

    del X_ft, art; gc.collect()

print(f'\nModelle: {MODELS_DIR.resolve()}')
print('GeoViz-Szenario "Nat. Modell" nach Backend-Neustart verfügbar.')
# Out:
# === Inferenz-Benchmark ===
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
# DIESEL : 648 Ausgaben  |  0.2 ms (±0.1 ms)  |  Ø t+1h = 1.929 EUR/L
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
# E5     : 648 Ausgaben  |  0.2 ms (±0.1 ms)  |  Ø t+1h = 2.058 EUR/L
# [AllGermany] quick_mode=True — using existing processed parquets (no raw-CSV scan). Pass quick_mode=False for the full 90-cell dataset.
# [quick_load] B29 parquet: (104751, 4), last=2026-05-20 23:00:00
# [quick_load] Spedition parquet: (104748, 5), last=2026-05-20 20:00:00
# [quick_load] Combined DataFrame: (104751, 27), 2014-06-08 → 2026-05-20
# E10    : 648 Ausgaben  |  0.2 ms (±0.1 ms)  |  Ø t+1h = 2.005 EUR/L
#
# Modelle: /home/jawasch/Documents/HS_Aalen/Sem1/PredictiveAnalytics/Projekt/Test_Spritpreise/data/models
# GeoViz-Szenario "Nat. Modell" nach Backend-Neustart verfügbar.
